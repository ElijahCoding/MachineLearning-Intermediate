# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
import pandas as pd

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
np.random.seed(42)

# %%
n_samples = 100

rng = np.random.rand(n_samples) * 10

y_gen = 0.5 * rng + 2 * np.random.randn(n_samples)

rng.shape, y_gen.shape
# Out:
# ((100,), (100,))

# %%
lr = LinearRegression()
lr.fit(rng.reshape(-1, 1), y_gen)
model_pred = lr.predict(rng.reshape(-1, 1))

# %%
plt.figure(figsize=(10, 8))
plt.scatter(rng, y_gen)
plt.plot(rng, model_pred)
print('Coefficient Estimate: ', lr.coef_)
# Out:
# Coefficient Estimate:  [0.55659613]
